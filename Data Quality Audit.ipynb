# %% [markdown]
# ## Data Quality Audit

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML

# %% [markdown]
# ### Import Data

# %%
df1 = pd.read_csv("D:\DATA ANALYTICS\PROJECTS\Subscription SaaS Customer Churn\Data\customers.csv")
df2 = pd.read_csv("D:\DATA ANALYTICS\PROJECTS\Subscription SaaS Customer Churn\Data\churn_status.csv")
df3 = pd.read_csv("D:\DATA ANALYTICS\PROJECTS\Subscription SaaS Customer Churn\Data\marketing_source.csv")
df4 = pd.read_csv("D:\DATA ANALYTICS\PROJECTS\Subscription SaaS Customer Churn\Data\payments.csv")
df5 = pd.read_csv("D:\DATA ANALYTICS\PROJECTS\Subscription SaaS Customer Churn\Data\subscriptions.csv")
df6 = pd.read_csv("D:\DATA ANALYTICS\PROJECTS\Subscription SaaS Customer Churn\Data\support_tickets.csv")
df7 = pd.read_csv(r"D:\DATA ANALYTICS\PROJECTS\Subscription SaaS Customer Churn\Data\usage_activity.csv")

# %% [markdown]
# ### Data Understanding

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       82 non-null     object
#  1   company_name      82 non-null     object
#  2   industry          82 non-null     object
#  3   country           82 non-null     object
#  4   city              73 non-null     object
#  5   signup_date       82 non-null     object
#  6   plan_type         82 non-null     object
#  7   employee_count    73 non-null     float64
#  8   contact_email     76 non-null     object
#  9   phone             71 non-null     object
#  10  account_owner     75 non-null     object
#  11  billing_email     70 non-null     object
#  12  customer_segment  73 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 8.5+ KB

# %%
display(HTML(f"""
<div style="display:flex; gap:30px;">  
<div>
             <h3> Customers T1 </h3>
             <p>fd :{df1.info()} </p>
             </div>

 <div>
             <h3> Churn Status T2 </h3>
             <p> vx:{df2.info()} </p>
             </div>       

<div>
             <h3> Marketing Source T3 </h3>
             <p> {df3.info()} </p>
             </div>

 <div>
             <h3> Payments T4 </h3>
             <p> {df4.info()} </p>
             </div>  

<div>
             <h3> Subscription T5</h3>
             <p> {df5.info()} </p>
             </div>

 <div>
             <h3> Support Tickets T6 </h3>
             <p> {df6.info()} </p>
             </div>  
    
 <div>
             <h3> Usage Activity T7 </h3>
             <p> {df7.info()} </p>
             </div>  
</div>  
            """))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       82 non-null     object
#  1   company_name      82 non-null     object
#  2   industry          82 non-null     object
#  3   country           82 non-null     object
#  4   city              73 non-null     object
#  5   signup_date       82 non-null     object
#  6   plan_type         82 non-null     object
#  7   employee_count    73 non-null     float64
#  8   contact_email     76 non-null     object
#  9   phone             71 non-null     object
#  10  account_owner     75 non-null     object
#  11  billing_email     70 non-null     object
#  12  customer_segment  73 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 8.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 12 columns):
# ...

# %%
df1.shape
# Out:
# (82, 13)

# %%
display(HTML(f"""
<div style="display:flex; gap:30px;">  
<div>
             <h3>table 1 </h3>
             <p>total RC: {df1.shape} </p>
             </div>

 <div>
             <h3>table 2 </h3>
             <p>total RC: {df1.shape} </p>
             </div>       
</div>  
            """))
# Out:
# <div style="display:flex; gap:30px;">
# <div>
#              <h3>table 1 </h3>
#              <p>total RC: (82, 13) </p>
#              </div>
#
#  <div>
#              <h3>table 2 </h3>
#              <p>total RC: (82, 13) </p>
#              </div>
# </div>

# %%
print("Descriptive Statistics:")
df1.describe()
# Out:
# Descriptive Statistics:
#        employee_count
# count       73.000000
# mean       169.219178
# std        248.216205
# min         -1.000000
# 25%         20.000000
# 50%         50.000000
# 75%        200.000000
# max       1000.000000

# %%
print("Missing values:")       
print(df1.isnull().sum())
print("\nTotal Misiing Values:", df1.isnull().sum().sum())
print("Total Missing Values Percentage:", ((df1.isnull().sum().sum()/df1.size)*100).round(2))
# Out:
# Missing values:
# customer_id          0
# company_name         0
# industry             0
# country              0
# city                 9
# signup_date          0
# plan_type            0
# employee_count       9
# contact_email        6
# phone               11
# account_owner        7
# billing_email       12
# customer_segment     9
# dtype: int64
#
# Total Misiing Values: 63
# Total Missing Values Percentage: 5.91

# %%
print("Duplicate Rows:")
df1.duplicated().sum()
print("\nTotal Duplicate Row:",df1.duplicated().sum())
# Out:
# Duplicate Rows:
#
# Total Duplicate Row: 1

# %%
({'duplicate ': [df1.duplicated().sum()]}),
({'duplicate ': [df1.duplicated().sum()]})
# Out:
# {'duplicate ': [np.int64(1)]}

# %%
df1["customer_id"]
# Out:
# 0     C001
# 1     C002
# 2     C003
# 3     C004
# 4     C005
#       ...
# 77    C078
# 78    C079
# 79    C080
# 80    C005
# 81    C012
# Name: customer_id, Length: 82, dtype: object

# %%
unique_id= set(df1["customer_id"])

# %%
len(unique_id)
# Out:
# 80
